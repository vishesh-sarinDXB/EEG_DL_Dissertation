# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
s01_svm = pd.read_csv('../summary/s01_low_performer_svm.csv')
s05_svm = pd.read_csv('../summary/s05_high_performer_svm.csv')
s06_svm = pd.read_csv('../summary/s06_mediocre_performer_svm.csv')

# %%
s01_svm['Type'] = 'Not Discriminative'
s05_svm['Type'] = 'High Performing'
s06_svm['Type'] = 'Discriminative'

# %%
final = s01_svm.append(s06_svm)#.reset_index().drop(columns = 'index')
final = final.append(s05_svm)#.reset_index().drop(columns = 'index')

# %%
sns.set_style('dark')

# %%
g = sns.FacetGrid(final, col = 'Type', sharex = False, sharey = False)#, height = 4)
g.map_dataframe(sns.lineplot)

# %%
final0 = final.loc[:, ['0', 'Type']]
final0['column'] = '0'
final1 =  final.loc[:, ['0.1', 'Type']]
final1 = final1.rename(columns = {'0.1': '0'})
final1['column'] = '0.1'

final2 =  final.loc[:, ['0.2', 'Type']]
final2 = final2.rename(columns = {'0.2': '0'})
final2['column'] = '0.2'

final3 =  final.loc[:, ['0.3', 'Type']]
final3 = final3.rename(columns = {'0.3': '0'})
final3['column'] = '0.3'

final4 =  final.loc[:, ['0.4', 'Type']]
final4 = final4.rename(columns = {'0.4': '0'})
final4['column'] = '0.4'

final5 =  final.loc[:, ['0.5', 'Type']]
final5 = final5.rename(columns = {'0.5': '0'})
final5['column'] = '0.5'

final6 =  final.loc[:, ['0.6', 'Type']]
final6 = final6.rename(columns = {'0.6': '0'})
final6['column'] = '0.6'

final7 =  final.loc[:, ['0.7', 'Type']]
final7 = final7.rename(columns = {'0.7': '0'})
final7['column'] = '0.7'

final8 =  final.loc[:, ['0.8', 'Type']]
final8 = final8.rename(columns = {'0.8': '0'})
final8['column'] = '0.8'

final9 =  final.loc[:, ['0.9', 'Type']]
final9 = final9.rename(columns = {'0.9': '0'})
final9['column'] = '0.9'


final_new = final0.append(final1)
final_new = final_new.append(final2)
final_new = final_new.append(final3)
final_new = final_new.append(final4)
final_new = final_new.append(final5)
final_new = final_new.append(final6)
final_new = final_new.append(final7)
final_new = final_new.append(final8)
final_new = final_new.append(final9)

# %%
g = sns.FacetGrid(final_new.reset_index(), col = 'Type', sharex = False, sharey = False)

g.map_dataframe(sns.lineplot, x = 'index', y = '0')

# %%
s01_svm = pd.read_csv('../summary/s01_low_performer_lstm.csv', header = None)

# %%
s01_svm.transpose()
# Out:
#            0         1         2         3         4         5         6  \
# 0   1.053305  2.071696  2.290924  1.209635  0.990047  0.844211  2.688733
# 1   0.740920  1.676181  2.010818  1.001577  0.824234  0.648616  2.246114
# 2   0.381765  1.130229  1.570551  0.744456  0.512646  0.391548  1.757827
# 3   0.194087  0.763193  1.187112  0.531813  0.322021  0.212636  1.218921
# 4   0.129984  0.504613  0.864351  0.352588  0.176016  0.131900  0.702971
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.145057  0.177096  0.692034  0.246576  0.137951  0.169540  0.130509
# 96  0.145055  0.177094  0.692032  0.246573  0.137952  0.169539  0.130509
# 97  0.145054  0.177091  0.692030  0.246570  0.137952  0.169538  0.130508
# 98  0.145054  0.177088  0.692028  0.246567  0.137953  0.169537  0.130507
# 99  0.145053  0.177086  0.692026  0.246565  0.137953  0.169536  0.130507
#
#            7         8         9
# 0   1.393835  1.239044  2.599099
# ...

# %%
s01_svm['type'] = 'something'

# %%
s01_svm = pd.read_csv('../summary/s01_low_performer_lstm.csv', header = None).transpose()
s05_svm = pd.read_csv('../summary/s05_high_performer_lstm.csv', header = None).transpose()
s06_svm = pd.read_csv('../summary/s06_mediocre_performer_lstm.csv', header = None).transpose()

# %%
s01_svm['Type'] = 'Not Discriminative'
s05_svm['Type'] = 'High Performing'
s06_svm['Type'] = 'Discriminative'

# %%
final = s01_svm.append(s06_svm)#.reset_index().drop(columns = 'index')
final = final.append(s05_svm)#.reset_index().drop(columns = 'index')

# %%
final0 = final.loc[:, [0, 'Type']]
final0['column'] = '0'
final1 =  final.loc[:, [1, 'Type']]
final1 = final1.rename(columns = {1: 0})
final1['column'] = '0.1'

# %%
final1
# Out:
#            0                Type column
# 0   2.071696  Not Discriminative    0.1
# 1   1.676181  Not Discriminative    0.1
# 2   1.130229  Not Discriminative    0.1
# 3   0.763193  Not Discriminative    0.1
# 4   0.504613  Not Discriminative    0.1
# ..       ...                 ...    ...
# 95  0.116201     High Performing    0.1
# 96  0.116201     High Performing    0.1
# 97  0.116202     High Performing    0.1
# 98  0.116202     High Performing    0.1
# 99  0.116202     High Performing    0.1
#
# [300 rows x 3 columns]

# %%
g = sns.FacetGrid(final, col = 'Type', sharex = False, sharey = False)#, xlim = (0, 100))#, height = 4)
g.map_dataframe(sns.lineplot)

# %%
final0 = final.loc[:, [0, 'Type']]
final0['column'] = '0'

final1 =  final.loc[:, [1, 'Type']]
final1 = final1.rename(columns = {1: 0})
final1['column'] = '0.1'

final2 =  final.loc[:, [2, 'Type']]
final2 = final2.rename(columns = {2: 0})
final2['column'] = '0.2'

final3 =  final.loc[:, [3, 'Type']]
final3 = final3.rename(columns = {3: 0})
final3['column'] = '0.3'

final4 =  final.loc[:, [4, 'Type']]
final4 = final4.rename(columns = {4: 0})
final4['column'] = '0.4'

final5 =  final.loc[:, [5, 'Type']]
final5 = final5.rename(columns = {5: 0})
final5['column'] = '0.5'

final6 =  final.loc[:, [6, 'Type']]
final6 = final6.rename(columns = {6: 0})
final6['column'] = '0.6'

final7 =  final.loc[:, [7, 'Type']]
final7 = final7.rename(columns = {7: 0})
final7['column'] = '0.7'

final8 =  final.loc[:, [8, 'Type']]
final8 = final8.rename(columns = {8: 0})
final8['column'] = '0.8'

final9 =  final.loc[:, [9, 'Type']]
final9 = final9.rename(columns = {9: 0})
final9['column'] = '0.9'


final_new = final0.append(final1)
final_new = final_new.append(final2)
final_new = final_new.append(final3)
final_new = final_new.append(final4)
final_new = final_new.append(final5)
final_new = final_new.append(final6)
final_new = final_new.append(final7)
final_new = final_new.append(final8)
final_new = final_new.append(final9)

# %%
final_new
# Out:
#            0                Type column
# 0   1.053305  Not Discriminative      0
# 1   0.740920  Not Discriminative      0
# 2   0.381765  Not Discriminative      0
# 3   0.194087  Not Discriminative      0
# 4   0.129984  Not Discriminative      0
# ..       ...                 ...    ...
# 95  0.350569     High Performing    0.9
# 96  0.350565     High Performing    0.9
# 97  0.350561     High Performing    0.9
# 98  0.350557     High Performing    0.9
# 99  0.350554     High Performing    0.9
#
# [3000 rows x 3 columns]

# %%
final_new.columns = ['0', 'Type', 'columns']

# %%
g = sns.FacetGrid(final_new.reset_index(), col = 'Type', sharex = False, sharey = False)

g.map_dataframe(sns.lineplot, x = 'index', y = '0')
