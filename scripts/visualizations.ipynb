# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
all_real = pd.read_csv('../summary/mi_real/all.csv')
all_cv = pd.read_csv('../summary/mi_cv/all/all.csv')
all_str = 'all'

all_channels_alphamu_real = pd.read_csv('../summary/mi_real/all_channels_alphamu.csv')
all_channels_alphamu_cv = pd.read_csv('../summary/mi_cv/all_channels_alphamu/all_channels_alphamu.csv')
all_channels_alphamu = 'all_channels_alphamu'

bio_channelsConly_alphamu_real = pd.read_csv('../summary/mi_real/bio_channelsConly_alphamu.csv')
bio_channelsConly_alphamu_cv = pd.read_csv('../summary/mi_cv/bio_channelsConly_alphamu/bio_channelsConly_alphamu.csv')
bio_channelsConly_alphamu = 'bio_channelsConly_alphamu'

bio_channelsOConly_alphamu_real = pd.read_csv('../summary/mi_real/bio_channelsOConly_alphamu.csv')
bio_channelsOConly_alphamu_cv = pd.read_csv('../summary/mi_cv/bio_channelsOConly_alphamu/bio_channelsOConly_alphamu.csv')
bio_channelsOConly_alphamu = 'bio_channelsOConly_alphamu'

bio_channelsOonly_alphamu_real = pd.read_csv('../summary/mi_real/bio_channelsOonly_alphamu.csv')
bio_channelsOonly_alphamu_cv = pd.read_csv('../summary/mi_cv/bio_channelsOonly_alphamu/bio_channelsOonly_alphamu.csv')
bio_channelsOonly_alphamu = 'bio_channelsOonly_alphamu'

bio_channelsOPT_real = pd.read_csv('../summary/mi_real/bio_channelsOPT.csv')
bio_channelsOPT_cv = pd.read_csv('../summary/mi_cv/bio_channelsOPT/bio_channelsOPT.csv')
bio_channelsOPT = 'bio_channelsOPT'

bio_channelsOPT_alphamu_real = pd.read_csv('../summary/mi_real/bio_channelsOPT_alphamu.csv')
bio_channelsOPT_alphamu_cv = pd.read_csv('../summary/mi_cv/bio_channelsOPT_alphamu/bio_channelsOPT_alphamu.csv')
bio_channelsOPT_alphamu = 'bio_channelsOPT_alphamu'

bio_channelsPT_real = pd.read_csv('../summary/mi_real/bio_channelsPT.csv')
bio_channelsPT_cv = pd.read_csv('../summary/mi_cv/bio_channelsPT/bio_channelsPT.csv')
bio_channelsPT = 'bio_channelsPT'

bio_channelsPT_alphamu_real = pd.read_csv('../summary/mi_real/bio_channelsPT_alphamu.csv')
bio_channelsPT_alphamu_cv = pd.read_csv('../summary/mi_cv/bio_channelsPT_alphamu/bio_channelsPT_alphamu.csv')
bio_channelsPT_alphamu = 'bio_channelsPT_alphamu_cv'

# %%
experiment = 'experiment'
data = 'data'
mi_real = 'mi_real'
mi_cv = 'mi_cv'

# %%
all_real[experiment] = all_str
all_real[data] = mi_real

all_cv[experiment] = all_str
all_cv[data] = mi_cv

all_channels_alphamu_real[experiment] = all_channels_alphamu
all_channels_alphamu_real[data] = mi_real

all_channels_alphamu_cv[experiment] = all_channels_alphamu
all_channels_alphamu_cv[data] = mi_cv

bio_channelsConly_alphamu_real[experiment] = bio_channelsConly_alphamu
bio_channelsConly_alphamu_real[data] = mi_real

bio_channelsConly_alphamu_cv[experiment] = bio_channelsConly_alphamu
bio_channelsConly_alphamu_cv[data] = mi_cv

bio_channelsOConly_alphamu_real[experiment] = bio_channelsOConly_alphamu
bio_channelsOConly_alphamu_real[data] = mi_real

bio_channelsOConly_alphamu_cv[experiment] = bio_channelsOConly_alphamu
bio_channelsOConly_alphamu_cv[data] = mi_cv

bio_channelsOonly_alphamu_real[experiment] = bio_channelsOonly_alphamu
bio_channelsOonly_alphamu_real[data] = mi_real

bio_channelsOonly_alphamu_cv[experiment] = bio_channelsOonly_alphamu
bio_channelsOonly_alphamu_cv[data] = mi_cv

bio_channelsOPT_real[experiment] = bio_channelsOPT
bio_channelsOPT_real[data] = mi_real

bio_channelsOPT_cv[experiment] = bio_channelsOPT
bio_channelsOPT_cv[data] = mi_cv

bio_channelsOPT_alphamu_real[experiment] = bio_channelsOPT_alphamu
bio_channelsOPT_alphamu_real[data] = mi_real

bio_channelsOPT_alphamu_cv[experiment] = bio_channelsOPT_alphamu
bio_channelsOPT_alphamu_cv[data] = mi_cv

bio_channelsPT_real[experiment] = bio_channelsPT
bio_channelsPT_real[data] = mi_real

bio_channelsPT_cv[experiment] = bio_channelsPT
bio_channelsPT_cv[data] = mi_cv

bio_channelsPT_alphamu_real[experiment] = bio_channelsPT_alphamu
bio_channelsPT_alphamu_real[data] = mi_real

bio_channelsPT_alphamu_cv[experiment] = bio_channelsPT_alphamu
bio_channelsPT_alphamu_cv[data] = mi_cv

# %%
final = all_real.append(all_cv).reset_index().drop(columns = 'index')

final = final.append(all_channels_alphamu_real).reset_index().drop(columns = 'index')

final = final.append(all_channels_alphamu_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsConly_alphamu_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsConly_alphamu_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOConly_alphamu_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOConly_alphamu_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOonly_alphamu_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOonly_alphamu_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOPT_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOPT_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOPT_alphamu_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOPT_alphamu_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsPT_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsPT_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsPT_alphamu_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsPT_alphamu_cv).reset_index().drop(columns = 'index')

# %%
len(all_real[all_real.loc[:, 'test_accuracy'] > 0.5].index)
# Out:
# 20

# %%
all_cv[all_cv.loc[:, 'test_accuracy'] > 0.5].describe()
# Out:
#        train_accuracy  test_accuracy  Precision_class1  Precision_class2  \
# count       27.000000      27.000000         27.000000         27.000000
# mean         0.906317       0.664444          0.669214          0.672908
# std          0.059927       0.178753          0.177247          0.172691
# min          0.801667       0.500000          0.511024          0.511515
# 25%          0.864444       0.530000          0.539694          0.542736
# 50%          0.902778       0.560000          0.585554          0.594928
# 75%          0.950833       0.757500          0.766547          0.759914
# max          1.000000       1.000000          1.000000          1.000000
#
#        Recall_class1  Recall_class2  F1_class1  F1_class2  \
# count      27.000000      27.000000  27.000000  27.000000
# mean        0.687446       0.651810   0.665625   0.648442
# std         0.165893       0.188816   0.177431   0.187388
# min         0.520887       0.465909   0.499686   0.487015
# 25%         0.553158       0.517414   0.531230   0.510906
# 50%         0.625833       0.555649   0.580109   0.531947
# 75%         0.762139       0.774534   0.750939   0.755467
# max         1.000000       1.000000   1.000000   1.000000
#
#        Precision_class1_train  Precision_class2_train  Recall_class1_train  \
# count               27.000000               27.000000            27.000000
# mean                 0.907427                0.906464             0.905523
# std                  0.059393                0.061208             0.062572
# min                  0.804868                0.799674             0.789919
# 25%                  0.864113                0.871316             0.869817
# 50%                  0.907206                0.901713             0.898879
# 75%                  0.948008                0.951538             0.951582
# max                  1.000000                1.000000             1.000000
#
#        Recall_class2_train  F1_class1_train  F1_class2_train
# count            27.000000        27.000000        27.000000
# mean              0.906937         0.906089         0.906320
# std               0.059809         0.060279         0.059779
# min               0.804150         0.801406         0.801435
# 25%               0.864896         0.865878         0.862581
# 50%               0.907611         0.902160         0.901998
# 75%               0.947675         0.951116         0.950470
# max               1.000000         1.000000         1.000000

# %%
len(bio_channelsOonly_alphamu_cv[bio_channelsOonly_alphamu_cv.loc[:, 'test_accuracy'] > 0.5].index)
# Out:
# 34

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.violinplot(x="experiment", y="test_accuracy", hue="data", data=final)#, split=True, rot = 90)
# Out:
# <AxesSubplot:xlabel='experiment', ylabel='test_accuracy'>

# %%
final
# Out:
#      train_accuracy  test_accuracy  Precision_class1  Precision_class2  \
# 0          0.760000          0.550          0.562500          0.541667
# 1          0.790000          0.600          0.600000          0.600000
# 2          0.915000          0.525          0.521739          0.529412
# 3          0.835000          0.525          0.526316          0.523810
# 4          1.000000          0.450          0.454545          0.444444
# ..              ...            ...               ...               ...
# 931        0.846667          0.500          0.482214          0.501811
# 932        0.990556          0.900          0.891263          0.909672
# 933        1.000000          1.000          1.000000          1.000000
# 934        0.795000          0.470          0.504740          0.492325
# 935        0.852778          0.535          0.534328          0.529951
#
#      Recall_class1  Recall_class2  F1_class1  F1_class2  \
# 0         0.450000       0.650000   0.500000   0.590909
# 1         0.600000       0.600000   0.600000   0.600000
# 2         0.600000       0.450000   0.558140   0.486486
# 3         0.500000       0.550000   0.512821   0.536585
# 4         0.500000       0.400000   0.476190   0.421053
# ..             ...            ...        ...        ...
# 931       0.451270       0.547436   0.454663   0.511061
# 932       0.890733       0.904992   0.884141   0.901362
# 933       1.000000       1.000000   1.000000   1.000000
# 934       0.519460       0.482249   0.479390   0.450365
# 935       0.510220       0.550917   0.512590   0.532217
#
#      Precision_class1_train  Precision_class2_train  Recall_class1_train  \
# 0                  0.754902                0.765306             0.770000
# 1                  0.768519                0.815217             0.830000
# 2                  0.936842                0.895238             0.890000
# 3                  0.825243                0.845361             0.850000
# 4                  1.000000                1.000000             1.000000
# ..                      ...                     ...                  ...
# 931                0.847892                0.846352             0.844929
# 932                0.984627                0.996654             0.996679
# 933                1.000000                1.000000             1.000000
# 934                0.786575                0.808133             0.808347
# 935                0.852754                0.853652             0.853102
#
#      Recall_class2_train  F1_class1_train  F1_class2_train  \
# 0               0.750000         0.762376         0.757576
# 1               0.750000         0.798077         0.781250
# 2               0.940000         0.912821         0.917073
# 3               0.820000         0.837438         0.832487
# 4               1.000000         1.000000         1.000000
# ..                   ...              ...              ...
# 931             0.847709         0.846115         0.846749
# 932             0.984468         0.990595         0.990502
# 933             1.000000         1.000000         1.000000
# 934             0.779589         0.795946         0.792084
# 935             0.852196         0.852625         0.852585
#
#                     experiment     data
# 0                          all  mi_real
# 1                          all  mi_real
# 2                          all  mi_real
# 3                          all  mi_real
# 4                          all  mi_real
# ..                         ...      ...
# 931  bio_channelsPT_alphamu_cv    mi_cv
# 932  bio_channelsPT_alphamu_cv    mi_cv
# 933  bio_channelsPT_alphamu_cv    mi_cv
# 934  bio_channelsPT_alphamu_cv    mi_cv
# 935  bio_channelsPT_alphamu_cv    mi_cv
#
# [936 rows x 16 columns]

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.violinplot(x="experiment", y="Precision_class1", hue="data", data=final)#, split=True, rot = 90)
# Out:
# <AxesSubplot:xlabel='experiment', ylabel='Precision_class1'>

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.violinplot(x="experiment", y="Recall_class1", hue="data", data=final,  rot = 90)
# Out:
# <AxesSubplot:xlabel='experiment', ylabel='Recall_class1'>

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.violinplot(x="experiment", y="F1_class1", hue="data", data=final,  rot = 90)
# Out:
# <AxesSubplot:xlabel='experiment', ylabel='F1_class1'>

# %%
final.groupby([experiment, data]).describe().to_csv('../summary/summary.csv')

# %%
final.groupby([experiment, data]).describe()
# Out:
#                                    train_accuracy                      \
#                                             count      mean       std
# experiment                 data
# all                        mi_cv             52.0  0.871581  0.063785
#                            mi_real           52.0  0.862067  0.068662
# all_channels_alphamu       mi_cv             52.0  0.867251  0.064891
#                            mi_real           52.0  0.855224  0.073533
# bio_channelsConly_alphamu  mi_cv             52.0  0.767504  0.094337
#                            mi_real           52.0  0.758077  0.098698
# bio_channelsOConly_alphamu mi_cv             52.0  0.792343  0.088732
#                            mi_real           52.0  0.786122  0.092283
# bio_channelsOPT            mi_cv             52.0  0.825509  0.076003
#                            mi_real           52.0  0.819968  0.077380
# bio_channelsOPT_alphamu    mi_cv             52.0  0.825308  0.075176
#                            mi_real           52.0  0.814407  0.080607
# bio_channelsOonly_alphamu  mi_cv             52.0  0.704980  0.119438
#                            mi_real           52.0  0.696074  0.125073
# bio_channelsPT             mi_cv             52.0  0.846179  0.068741
#                            mi_real           52.0  0.837356  0.073716
# bio_channelsPT_alphamu_cv  mi_cv             52.0  0.841471  0.070286
#                            mi_real           52.0  0.832292  0.077197
#
#                                                                             \
#                                          min       25%       50%       75%
# experiment                 data
# all                        mi_cv    0.746759  0.822523  0.866111  0.905139
#                            mi_real  0.735000  0.815000  0.860000  0.896250
# all_channels_alphamu       mi_cv    0.734722  0.819028  0.857500  0.894583
#                            mi_real  0.695833  0.807500  0.850000  0.890000
# bio_channelsConly_alphamu  mi_cv    0.638889  0.711528  0.732500  0.784861
#                            mi_real  0.625000  0.694167  0.727500  0.778750
# bio_channelsOConly_alphamu mi_cv    0.660000  0.739167  0.766667  0.817639
#                            mi_real  0.640000  0.730000  0.763750  0.816250
# bio_channelsOPT            mi_cv    0.702778  0.784167  0.809722  0.842222
#                            mi_real  0.710000  0.770625  0.802500  0.842500
# bio_channelsOPT_alphamu    mi_cv    0.714815  0.780764  0.806667  0.844028
#                            mi_real  0.679167  0.770000  0.800000  0.826250
# bio_channelsOonly_alphamu  mi_cv    0.565000  0.623750  0.658333  0.745694
#                            mi_real  0.540000  0.616250  0.640000  0.751250
# bio_channelsPT             mi_cv    0.724074  0.797361  0.836111  0.861389
#                            mi_real  0.704167  0.778750  0.830000  0.860000
# bio_channelsPT_alphamu_cv  mi_cv    0.716667  0.795972  0.827778  0.860556
#                            mi_real  0.691667  0.775000  0.825000  0.861250
#
#                                         test_accuracy            ...  \
#                                     max         count      mean  ...
# experiment                 data                                  ...
# all                        mi_cv    1.0          52.0  0.569359  ...
#                            mi_real  1.0          52.0  0.505769  ...
# all_channels_alphamu       mi_cv    1.0          52.0  0.567244  ...
#                            mi_real  1.0          52.0  0.495673  ...
# bio_channelsConly_alphamu  mi_cv    1.0          52.0  0.590112  ...
#                            mi_real  1.0          52.0  0.532212  ...
# bio_channelsOConly_alphamu mi_cv    1.0          52.0  0.581026  ...
#                            mi_real  1.0          52.0  0.499519  ...
# bio_channelsOPT            mi_cv    1.0          52.0  0.587468  ...
#                            mi_real  1.0          52.0  0.525962  ...
# bio_channelsOPT_alphamu    mi_cv    1.0          52.0  0.582356  ...
#                            mi_real  1.0          52.0  0.525000  ...
# bio_channelsOonly_alphamu  mi_cv    1.0          52.0  0.599167  ...
#                            mi_real  1.0          52.0  0.510096  ...
# bio_channelsPT             mi_cv    1.0          52.0  0.576587  ...
#                            mi_real  1.0          52.0  0.510577  ...
# bio_channelsPT_alphamu_cv  mi_cv    1.0          52.0  0.575000  ...
#                            mi_real  1.0          52.0  0.512981  ...
#
#                                    F1_class1_train      F1_class2_train  \
#                                                75%  max           count
# experiment                 data
# all                        mi_cv          0.905412  1.0            52.0
#                            mi_real        0.896582  1.0            52.0
# all_channels_alphamu       mi_cv          0.893828  1.0            52.0
#                            mi_real        0.890272  1.0            52.0
# bio_channelsConly_alphamu  mi_cv          0.785317  1.0            52.0
#                            mi_real        0.785893  1.0            52.0
# bio_channelsOConly_alphamu mi_cv          0.818241  1.0            52.0
#                            mi_real        0.816486  1.0            52.0
# bio_channelsOPT            mi_cv          0.843330  1.0            52.0
#                            mi_real        0.845173  1.0            52.0
# bio_channelsOPT_alphamu    mi_cv          0.845611  1.0            52.0
#                            mi_real        0.822128  1.0            52.0
# bio_channelsOonly_alphamu  mi_cv          0.745293  1.0            52.0
#                            mi_real        0.749038  1.0            52.0
# bio_channelsPT             mi_cv          0.860569  1.0            52.0
#                            mi_real        0.858939  1.0            52.0
# bio_channelsPT_alphamu_cv  mi_cv          0.858344  1.0            52.0
#                            mi_real        0.860776  1.0            52.0
#
#                                                                             \
#                                         mean       std       min       25%
# experiment                 data
# all                        mi_cv    0.870965  0.064311  0.751327  0.821367
#                            mi_real  0.861268  0.069141  0.743961  0.813263
# all_channels_alphamu       mi_cv    0.866349  0.065527  0.737314  0.817456
#                            mi_real  0.854412  0.074298  0.702041  0.801523
# bio_channelsConly_alphamu  mi_cv    0.765838  0.095472  0.643848  0.707724
#                            mi_real  0.754690  0.100918  0.611399  0.689734
# bio_channelsOConly_alphamu mi_cv    0.790005  0.090393  0.655693  0.729422
#                            mi_real  0.784384  0.094004  0.638743  0.722947
# bio_channelsOPT            mi_cv    0.825532  0.076166  0.704750  0.787238
#                            mi_real  0.820489  0.077284  0.694737  0.775717
# bio_channelsOPT_alphamu    mi_cv    0.825267  0.075237  0.721998  0.781288
#                            mi_real  0.814946  0.079885  0.698039  0.772580
# bio_channelsOonly_alphamu  mi_cv    0.703981  0.121469  0.542748  0.628093
#                            mi_real  0.699103  0.124700  0.506329  0.612862
# bio_channelsPT             mi_cv    0.845586  0.069441  0.727353  0.793879
#                            mi_real  0.835323  0.076025  0.695279  0.774526
# bio_channelsPT_alphamu_cv  mi_cv    0.840164  0.071536  0.718853  0.790884
#                            mi_real  0.831264  0.078427  0.694215  0.773471
#
#
#                                          50%       75%  max
# experiment                 data
# all                        mi_cv    0.865975  0.904747  1.0
#                            mi_real  0.859208  0.895869  1.0
# all_channels_alphamu       mi_cv    0.856265  0.894603  1.0
#                            mi_real  0.847680  0.889167  1.0
# bio_channelsConly_alphamu  mi_cv    0.732924  0.783903  1.0
#                            mi_real  0.724606  0.777210  1.0
# bio_channelsOConly_alphamu mi_cv    0.762543  0.816645  1.0
#                            mi_real  0.762397  0.818429  1.0
# bio_channelsOPT            mi_cv    0.808564  0.843184  1.0
#                            mi_real  0.803971  0.842169  1.0
# bio_channelsOPT_alphamu    mi_cv    0.806033  0.842154  1.0
#                            mi_real  0.794995  0.831522  1.0
# bio_channelsOonly_alphamu  mi_cv    0.661479  0.745786  1.0
#                            mi_real  0.657275  0.752744  1.0
# bio_channelsPT             mi_cv    0.832894  0.862796  1.0
#                            mi_real  0.830197  0.862185  1.0
# bio_channelsPT_alphamu_cv  mi_cv    0.828177  0.862468  1.0
#                            mi_real  0.825557  0.861424  1.0
#
# [18 rows x 112 columns]

# %%
cols = [('test_accuracy', 'mean'), ('test_accuracy', 'std'),
        ('Precision_class1', 'mean'), ('Precision_class1', 'std'),
        ('Recall_class1', 'mean'), ('Recall_class1', 'std'), 
        ('F1_class1', 'mean'), ('F1_class1', 'std')]

# %%
final.groupby([experiment, data]).describe().loc[:, cols].sort_values(by = [('test_accuracy', 'mean')]).to_csv('../summary/summary_valMetricsOnly_Class1_sortedByAccuracy.csv')

# %%
cols = [('test_accuracy', 'mean'), ('test_accuracy', 'std'),
        ('Precision_class2', 'mean'), ('Precision_class2', 'std'),
        ('Recall_class2', 'mean'), ('Recall_class2', 'std'), 
        ('F1_class2', 'mean'), ('F1_class2', 'std')]

# %%
final.groupby([experiment, data]).describe().loc[:, cols].sort_values(by = [('test_accuracy', 'mean')]).to_csv('../summary/summary_valMetricsOnly_Class2_sortedByAccuracy.csv')

# %%
final.groupby([data]).describe().loc[:, ()]
# Out:
#         train_accuracy                                                 \
#                  count      mean       std    min       25%       50%
# data
# mi_cv            468.0  0.815792  0.095518  0.565  0.756389  0.812222
# mi_real          468.0  0.806843  0.099477  0.540  0.745625  0.805000
#
#                        test_accuracy            ... F1_class1_train       \
#               75%  max         count      mean  ...             75%  max
# data                                            ...
# mi_cv    0.864028  1.0         468.0  0.580924  ...        0.864385  1.0
# mi_real  0.860000  1.0         468.0  0.513088  ...        0.861424  1.0
#
#         F1_class2_train                                                    \
#                   count      mean       std       min       25%       50%
# data
# mi_cv             468.0  0.814854  0.096483  0.542748  0.755477  0.813948
# mi_real           468.0  0.806209  0.099851  0.506329  0.743961  0.804020
#
#
#               75%  max
# data
# mi_cv    0.864591  1.0
# mi_real  0.861840  1.0
#
# [2 rows x 112 columns]
