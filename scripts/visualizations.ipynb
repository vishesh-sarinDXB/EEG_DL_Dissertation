# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
all_real = pd.read_csv('../summary/mi_real/all/all.csv').drop(columns = 'Unnamed: 0')
all_cv = pd.read_csv('../summary/mi_cv/all/all.csv').drop(columns = 'Unnamed: 0')
all_str = 'all'


# all_145_real = pd.read_csv('../summary/mi_real/all_145/all_145.csv').drop(columns = 'Unnamed: 0')
# all_145_cv = pd.read_csv('../summary/mi_cv/all_145/all_145.csv').drop(columns = 'Unnamed: 0')
# all_145 = 'all_145'


all_channels_alphamu_real = pd.read_csv\
('../summary/mi_real/all_channels_alphamu/all_channels_alphamu.csv')\
.drop(columns = 'Unnamed: 0')

all_channels_alphamu_cv = pd.read_csv\
('../summary/mi_cv/all_channels_alphamu/all_channels_alphamu.csv')\
.drop(columns = 'Unnamed: 0')

all_channels_alphamu = 'all_channels_alphamu'


bio_channelsConly_alphamu_real = pd.read_csv\
('../summary/mi_real/bio_channelsConly_alphamu/bio_channelsConly_alphamu.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsConly_alphamu_cv = pd.read_csv\
('../summary/mi_cv/bio_channelsConly_alphamu/bio_channelsConly_alphamu.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsConly_alphamu = 'bio_channelsConly_alphamu'


bio_channelsOConly_alphamu_real = pd.read_csv\
('../summary/mi_real/bio_channelsOConly_alphamu/bio_channelsOConly_alphamu.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsOConly_alphamu_cv = pd.read_csv\
('../summary/mi_cv/bio_channelsOConly_alphamu/bio_channelsOConly_alphamu.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsOConly_alphamu = 'bio_channelsOConly_alphamu'


bio_channelsOonly_alphamu_real = pd.read_csv\
('../summary/mi_real/bio_channelsOonly_alphamu/bio_channelsOonly_alphamu.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsOonly_alphamu_cv = pd.read_csv\
('../summary/mi_cv/bio_channelsOonly_alphamu/bio_channelsOonly_alphamu.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsOonly_alphamu = 'bio_channelsOonly_alphamu'


bio_channelsOPT_real = pd.read_csv\
('../summary/mi_real/bio_channelsOPT/bio_channelsOPT.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsOPT_cv = pd.read_csv\
('../summary/mi_cv/bio_channelsOPT/bio_channelsOPT.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsOPT = 'bio_channelsOPT'


# bio_channelsOPT_145_real = pd.read_csv\
# ('../summary/mi_real/bio_channelsOPT_145/bio_channelsOPT_145.csv')\
# .drop(columns = 'Unnamed: 0')

# bio_channelsOPT_145_cv = pd.read_csv\
# ('../summary/mi_cv/bio_channelsOPT_145/bio_channelsOPT_145.csv')\
# .drop(columns = 'Unnamed: 0')

# bio_channelsOPT_145 = 'bio_channelsOPT_145'


bio_channelsOPT_alphamu_real = pd.read_csv\
('../summary/mi_real/bio_channelsOPT_alphamu/bio_channelsOPT_alphamu.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsOPT_alphamu_cv = pd.read_csv\
('../summary/mi_cv/bio_channelsOPT_alphamu/bio_channelsOPT_alphamu.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsOPT_alphamu = 'bio_channelsOPT_alphamu'


bio_channelsPT_real = pd.read_csv\
('../summary/mi_real/bio_channelsPT/bio_channelsPT.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsPT_cv = pd.read_csv\
('../summary/mi_cv/bio_channelsPT/bio_channelsPT.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsPT = 'bio_channelsPT'


# bio_channelsPT_145_real = pd.read_csv\
# ('../summary/mi_real/bio_channelsPT_145/bio_channelsPT_145.csv')\
# .drop(columns = 'Unnamed: 0')

# bio_channelsPT_145_cv = pd.read_csv\
# ('../summary/mi_cv/bio_channelsPT_145/bio_channelsPT_145.csv')\
# .drop(columns = 'Unnamed: 0')

# bio_channelsPT_145 = 'bio_channelsPT_145'


bio_channelsPT_alphamu_real = pd.read_csv\
('../summary/mi_real/bio_channelsPT_alphamu/bio_channelsPT_alphamu.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsPT_alphamu_cv = pd.read_csv\
('../summary/mi_cv/bio_channelsPT_alphamu/bio_channelsPT_alphamu.csv')\
.drop(columns = 'Unnamed: 0')

bio_channelsPT_alphamu = 'bio_channelsPT_alphamu'

# %%
bio_channelsPT_alphamu_cv
# Out:
#       train_accuracy  test_accuracy  Precision_class1  Precision_class2  \
# 0           0.750000           0.70          0.600000          0.800000
# 1           0.777778           0.40          0.416667          0.375000
# 2           0.777778           0.50          1.000000          0.411765
# 3           0.744444           0.55          0.500000          0.583333
# 4           0.727778           0.55          0.583333          0.500000
# ...              ...            ...               ...               ...
# 5195        0.872222           0.50          0.416667          0.625000
# 5196        0.888889           0.60          0.666667          0.545455
# 5197        0.838889           0.55          0.545455          0.555556
# 5198        0.861111           0.60          0.285714          0.769231
# 5199        0.822222           0.70          0.666667          0.727273
#
#       Recall_class1  Recall_class2  F1_class1  F1_class2  \
# 0          0.750000       0.666667   0.666667   0.727273
# 1          0.500000       0.300000   0.454545   0.333333
# 2          0.230769       1.000000   0.375000   0.583333
# 3          0.444444       0.636364   0.470588   0.608696
# 4          0.636364       0.444444   0.608696   0.470588
# ...             ...            ...        ...        ...
# 5195       0.625000       0.416667   0.500000   0.500000
# 5196       0.545455       0.666667   0.600000   0.600000
# 5197       0.600000       0.500000   0.571429   0.526316
# 5198       0.400000       0.666667   0.333333   0.714286
# 5199       0.666667       0.727273   0.666667   0.727273
#
#       Precision_class1_train  Precision_class2_train  Recall_class1_train  \
# 0                   0.737374                0.765432             0.793478
# 1                   0.760417                0.797619             0.811111
# 2                   0.776471                0.778947             0.758621
# 3                   0.718447                0.779221             0.813187
# 4                   0.700000                0.762500             0.786517
# ...                      ...                     ...                  ...
# 5195                0.887640                0.857143             0.858696
# 5196                0.887640                0.890110             0.887640
# 5197                0.835165                0.842697             0.844444
# 5198                0.864583                0.857143             0.873684
# 5199                0.831461                0.813187             0.813187
#
#       Recall_class2_train  F1_class1_train  F1_class2_train
# 0                0.704545         0.764398         0.733728
# 1                0.744444         0.784946         0.770115
# 2                0.795699         0.767442         0.787234
# 3                0.674157         0.762887         0.722892
# 4                0.670330         0.740741         0.713450
# ...                   ...              ...              ...
# 5195             0.886364         0.872928         0.871508
# 5196             0.890110         0.887640         0.890110
# 5197             0.833333         0.839779         0.837989
# 5198             0.847059         0.869110         0.852071
# 5199             0.831461         0.822222         0.822222
#
# [5200 rows x 14 columns]

# %%
experiment = 'experiment'
data = 'data'
mi_real = 'mi_real'
mi_cv = 'mi_cv'

# %%
all_real[experiment] = all_str
all_real[data] = mi_real

all_cv[experiment] = all_str
all_cv[data] = mi_cv

# all_145_real[experiment] = all_145
# all_145_real[data] = mi_real

# all_145_cv[experiment] = all_145
# all_145_cv[data] = mi_cv

all_channels_alphamu_real[experiment] = all_channels_alphamu
all_channels_alphamu_real[data] = mi_real

all_channels_alphamu_cv[experiment] = all_channels_alphamu
all_channels_alphamu_cv[data] = mi_cv

bio_channelsConly_alphamu_real[experiment] = bio_channelsConly_alphamu
bio_channelsConly_alphamu_real[data] = mi_real

bio_channelsConly_alphamu_cv[experiment] = bio_channelsConly_alphamu
bio_channelsConly_alphamu_cv[data] = mi_cv

bio_channelsOConly_alphamu_real[experiment] = bio_channelsOConly_alphamu
bio_channelsOConly_alphamu_real[data] = mi_real

bio_channelsOConly_alphamu_cv[experiment] = bio_channelsOConly_alphamu
bio_channelsOConly_alphamu_cv[data] = mi_cv

bio_channelsOonly_alphamu_real[experiment] = bio_channelsOonly_alphamu
bio_channelsOonly_alphamu_real[data] = mi_real

bio_channelsOonly_alphamu_cv[experiment] = bio_channelsOonly_alphamu
bio_channelsOonly_alphamu_cv[data] = mi_cv

bio_channelsOPT_real[experiment] = bio_channelsOPT
bio_channelsOPT_real[data] = mi_real

bio_channelsOPT_cv[experiment] = bio_channelsOPT
bio_channelsOPT_cv[data] = mi_cv

# bio_channelsOPT_145_real[experiment] = bio_channelsOPT_145
# bio_channelsOPT_145_real[data] = mi_real

# bio_channelsOPT_145_cv[experiment] = bio_channelsOPT_145
# bio_channelsOPT_145_cv[data] = mi_cv

bio_channelsOPT_alphamu_real[experiment] = bio_channelsOPT_alphamu
bio_channelsOPT_alphamu_real[data] = mi_real

bio_channelsOPT_alphamu_cv[experiment] = bio_channelsOPT_alphamu
bio_channelsOPT_alphamu_cv[data] = mi_cv

bio_channelsPT_real[experiment] = bio_channelsPT
bio_channelsPT_real[data] = mi_real

bio_channelsPT_cv[experiment] = bio_channelsPT
bio_channelsPT_cv[data] = mi_cv

# bio_channelsPT_145_real[experiment] = bio_channelsPT_145
# bio_channelsPT_145_real[data] = mi_real

# bio_channelsPT_145_cv[experiment] = bio_channelsPT_145
# bio_channelsPT_145_cv[data] = mi_cv

bio_channelsPT_alphamu_real[experiment] = bio_channelsPT_alphamu
bio_channelsPT_alphamu_real[data] = mi_real

bio_channelsPT_alphamu_cv[experiment] = bio_channelsPT_alphamu
bio_channelsPT_alphamu_cv[data] = mi_cv

# %%
final = all_real.append(all_cv).reset_index().drop(columns = 'index')

# final = final.append(all_145_real).reset_index().drop(columns = 'index')

# final = final.append(all_145_cv).reset_index().drop(columns = 'index')

final = final.append(all_channels_alphamu_real).reset_index().drop(columns = 'index')

final = final.append(all_channels_alphamu_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsConly_alphamu_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsConly_alphamu_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOConly_alphamu_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOConly_alphamu_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOonly_alphamu_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOonly_alphamu_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOPT_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOPT_cv).reset_index().drop(columns = 'index')

# final = final.append(bio_channelsOPT_145_real).reset_index().drop(columns = 'index')

# final = final.append(bio_channelsOPT_145_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOPT_alphamu_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsOPT_alphamu_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsPT_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsPT_cv).reset_index().drop(columns = 'index')

# final = final.append(bio_channelsPT_145_real).reset_index().drop(columns = 'index')

# final = final.append(bio_channelsPT_145_cv).reset_index().drop(columns = 'index')

final = final.append(bio_channelsPT_alphamu_real).reset_index().drop(columns = 'index')

final = final.append(bio_channelsPT_alphamu_cv).reset_index().drop(columns = 'index')

# %%
final
# Out:
#        train_accuracy  test_accuracy  Precision_class1  Precision_class2  \
# 0            0.806250          0.500          0.500000          0.500000
# 1            0.818750          0.475          0.476190          0.473684
# 2            0.912500          0.575          0.571429          0.578947
# 3            0.862500          0.500          0.500000          0.500000
# 4            1.000000          0.425          0.444444          0.384615
# ...               ...            ...               ...               ...
# 51475        0.872222          0.500          0.416667          0.625000
# 51476        0.888889          0.600          0.666667          0.545455
# 51477        0.838889          0.550          0.545455          0.555556
# 51478        0.861111          0.600          0.285714          0.769231
# 51479        0.822222          0.700          0.666667          0.727273
#
#        Recall_class1  Recall_class2  F1_class1  F1_class2  \
# 0           0.500000       0.500000   0.500000   0.500000
# 1           0.500000       0.450000   0.487805   0.461538
# 2           0.600000       0.550000   0.585366   0.564103
# 3           0.650000       0.350000   0.565217   0.411765
# 4           0.600000       0.250000   0.510638   0.303030
# ...              ...            ...        ...        ...
# 51475       0.625000       0.416667   0.500000   0.500000
# 51476       0.545455       0.666667   0.600000   0.600000
# 51477       0.600000       0.500000   0.571429   0.526316
# 51478       0.400000       0.666667   0.333333   0.714286
# 51479       0.666667       0.727273   0.666667   0.727273
#
#        Precision_class1_train  Precision_class2_train  Recall_class1_train  \
# 0                    0.795181                0.818182             0.825000
# 1                    0.784946                0.865672             0.890244
# 2                    0.943662                0.887640             0.870130
# 3                    0.847059                0.880000             0.888889
# 4                    1.000000                1.000000             1.000000
# ...                       ...                     ...                  ...
# 51475                0.887640                0.857143             0.858696
# 51476                0.887640                0.890110             0.887640
# 51477                0.835165                0.842697             0.844444
# 51478                0.864583                0.857143             0.873684
# 51479                0.831461                0.813187             0.813187
#
#        Recall_class2_train  F1_class1_train  F1_class2_train  \
# 0                 0.787500         0.809816         0.802548
# 1                 0.743590         0.834286         0.800000
# 2                 0.951807         0.905405         0.918605
# 3                 0.835443         0.867470         0.857143
# 4                 1.000000         1.000000         1.000000
# ...                    ...              ...              ...
# 51475             0.886364         0.872928         0.871508
# 51476             0.890110         0.887640         0.890110
# 51477             0.833333         0.839779         0.837989
# 51478             0.847059         0.869110         0.852071
# 51479             0.831461         0.822222         0.822222
#
#                    experiment     data
# 0                         all  mi_real
# 1                         all  mi_real
# 2                         all  mi_real
# 3                         all  mi_real
# 4                         all  mi_real
# ...                       ...      ...
# 51475  bio_channelsPT_alphamu    mi_cv
# 51476  bio_channelsPT_alphamu    mi_cv
# 51477  bio_channelsPT_alphamu    mi_cv
# 51478  bio_channelsPT_alphamu    mi_cv
# 51479  bio_channelsPT_alphamu    mi_cv
#
# [51480 rows x 16 columns]

# %%
import scipy.stats as stats

# %%
# stats.ttest_ind(a=all_cv['test_accuracy'],b=all_cv2['test_accuracy'],equal_var=False)

# %%
all_real[all_real.loc[:, 'test_accuracy'] > 0.5].describe()
# Out:
#        train_accuracy  test_accuracy  Precision_class1  Precision_class2  \
# count      240.000000     240.000000        240.000000        240.000000
# mean         0.887778       0.586458          0.585681          0.599879
# std          0.068441       0.061143          0.055689          0.087676
# min          0.729167       0.525000          0.516129          0.518519
# 25%          0.831250       0.550000          0.538462          0.541667
# 50%          0.893750       0.575000          0.571429          0.571429
# 75%          0.931250       0.625000          0.615385          0.626645
# max          1.000000       0.825000          0.750000          1.000000
#
#        Recall_class1  Recall_class2   F1_class1   F1_class2  \
# count     240.000000     240.000000  240.000000  240.000000
# mean        0.604167       0.568750    0.586358    0.573542
# std         0.146019       0.125439    0.083857    0.081507
# min         0.300000       0.200000    0.400000    0.307692
# 25%         0.500000       0.500000    0.526316    0.529412
# 50%         0.600000       0.600000    0.582157    0.578947
# 75%         0.700000       0.650000    0.634146    0.622222
# max         1.000000       0.850000    0.851064    0.787879
#
#        Precision_class1_train  Precision_class2_train  Recall_class1_train  \
# count              240.000000              240.000000           240.000000
# mean                 0.886555                0.890290             0.889973
# std                  0.069759                0.070199             0.072004
# min                  0.715789                0.719626             0.700000
# 25%                  0.833333                0.837432             0.843117
# 50%                  0.890244                0.891068             0.892212
# 75%                  0.936100                0.941347             0.940476
# max                  1.000000                1.000000             1.000000
#
#        Recall_class2_train  F1_class1_train  F1_class2_train
# count           240.000000       240.000000       240.000000
# mean              0.884996         0.887846         0.887217
# std               0.072848         0.068506         0.069195
# min               0.708861         0.723404         0.731959
# 25%               0.839506         0.829878         0.834356
# 50%               0.884168         0.891892         0.888194
# 75%               0.939759         0.933728         0.930433
# max               1.000000         1.000000         1.000000

# %%
all_cv[all_cv.loc[:, 'test_accuracy'] > 0.5].describe()
# Out:
#        train_accuracy  test_accuracy  Precision_class1  Precision_class2  \
# count     2695.000000    2695.000000       2695.000000       2695.000000
# mean         0.893939       0.707560          0.708623          0.711402
# std          0.071408       0.158579          0.188075          0.185052
# min          0.675926       0.541667          0.142857          0.200000
# 25%          0.838889       0.600000          0.555556          0.571429
# 50%          0.894444       0.650000          0.666667          0.666667
# 75%          0.972222       0.800000          0.875000          0.875000
# max          1.000000       1.000000          1.000000          1.000000
#
#        Recall_class1  Recall_class2    F1_class1    F1_class2  \
# count    2695.000000    2695.000000  2695.000000  2695.000000
# mean        0.711842       0.707629     0.699376     0.698206
# std         0.189875       0.192301     0.173870     0.173683
# min         0.125000       0.200000     0.181818     0.200000
# 25%         0.566964       0.555556     0.571429     0.571429
# 50%         0.692308       0.692308     0.666667     0.666667
# 75%         0.875000       0.875000     0.823529     0.818182
# max         1.000000       1.000000     1.000000     1.000000
#
#        Precision_class1_train  Precision_class2_train  Recall_class1_train  \
# count             2695.000000             2695.000000          2695.000000
# mean                 0.894016                0.895247             0.894958
# std                  0.073508                0.072208             0.073846
# min                  0.669811                0.678899             0.644860
# 25%                  0.837209                0.844300             0.846154
# 50%                  0.894118                0.892857             0.891304
# 75%                  0.965909                0.964706             0.965909
# max                  1.000000                1.000000             1.000000
#
#        Recall_class2_train  F1_class1_train  F1_class2_train
# count          2695.000000      2695.000000      2695.000000
# mean              0.892749         0.894042         0.893541
# std               0.076509         0.071342         0.072055
# min               0.662921         0.669811         0.681818
# 25%               0.839080         0.839779         0.838517
# 50%               0.893617         0.892473         0.892655
# 75%               0.965909         0.970929         0.970929
# max               1.000000         1.000000         1.000000

# %%
len(bio_channelsOonly_alphamu_cv[bio_channelsOonly_alphamu_cv.loc[:, 'test_accuracy'] > 0.5].index)
# Out:
# 3097

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.violinplot(x="experiment", y="test_accuracy", hue="data", data=final)#, split=True, rot = 90)
# Out:
# <AxesSubplot:xlabel='experiment', ylabel='test_accuracy'>

# %%
final
# Out:
#        train_accuracy  test_accuracy  Precision_class1  Precision_class2  \
# 0            0.806250          0.500          0.500000          0.500000
# 1            0.818750          0.475          0.476190          0.473684
# 2            0.912500          0.575          0.571429          0.578947
# 3            0.862500          0.500          0.500000          0.500000
# 4            1.000000          0.425          0.444444          0.384615
# ...               ...            ...               ...               ...
# 51475        0.872222          0.500          0.416667          0.625000
# 51476        0.888889          0.600          0.666667          0.545455
# 51477        0.838889          0.550          0.545455          0.555556
# 51478        0.861111          0.600          0.285714          0.769231
# 51479        0.822222          0.700          0.666667          0.727273
#
#        Recall_class1  Recall_class2  F1_class1  F1_class2  \
# 0           0.500000       0.500000   0.500000   0.500000
# 1           0.500000       0.450000   0.487805   0.461538
# 2           0.600000       0.550000   0.585366   0.564103
# 3           0.650000       0.350000   0.565217   0.411765
# 4           0.600000       0.250000   0.510638   0.303030
# ...              ...            ...        ...        ...
# 51475       0.625000       0.416667   0.500000   0.500000
# 51476       0.545455       0.666667   0.600000   0.600000
# 51477       0.600000       0.500000   0.571429   0.526316
# 51478       0.400000       0.666667   0.333333   0.714286
# 51479       0.666667       0.727273   0.666667   0.727273
#
#        Precision_class1_train  Precision_class2_train  Recall_class1_train  \
# 0                    0.795181                0.818182             0.825000
# 1                    0.784946                0.865672             0.890244
# 2                    0.943662                0.887640             0.870130
# 3                    0.847059                0.880000             0.888889
# 4                    1.000000                1.000000             1.000000
# ...                       ...                     ...                  ...
# 51475                0.887640                0.857143             0.858696
# 51476                0.887640                0.890110             0.887640
# 51477                0.835165                0.842697             0.844444
# 51478                0.864583                0.857143             0.873684
# 51479                0.831461                0.813187             0.813187
#
#        Recall_class2_train  F1_class1_train  F1_class2_train  \
# 0                 0.787500         0.809816         0.802548
# 1                 0.743590         0.834286         0.800000
# 2                 0.951807         0.905405         0.918605
# 3                 0.835443         0.867470         0.857143
# 4                 1.000000         1.000000         1.000000
# ...                    ...              ...              ...
# 51475             0.886364         0.872928         0.871508
# 51476             0.890110         0.887640         0.890110
# 51477             0.833333         0.839779         0.837989
# 51478             0.847059         0.869110         0.852071
# 51479             0.831461         0.822222         0.822222
#
#                    experiment     data
# 0                         all  mi_real
# 1                         all  mi_real
# 2                         all  mi_real
# 3                         all  mi_real
# 4                         all  mi_real
# ...                       ...      ...
# 51475  bio_channelsPT_alphamu    mi_cv
# 51476  bio_channelsPT_alphamu    mi_cv
# 51477  bio_channelsPT_alphamu    mi_cv
# 51478  bio_channelsPT_alphamu    mi_cv
# 51479  bio_channelsPT_alphamu    mi_cv
#
# [51480 rows x 16 columns]

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.violinplot(x="experiment", y="Precision_class1", hue="data", data=final)#, split=True, rot = 90)
# Out:
# <AxesSubplot:xlabel='experiment', ylabel='Precision_class1'>

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.violinplot(x="experiment", y="Recall_class1", hue="data", data=final,  rot = 90)
# Out:
# <AxesSubplot:xlabel='experiment', ylabel='Recall_class1'>

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.violinplot(x="experiment", y="F1_class1", hue="data", data=final,  rot = 90)
# Out:
# <AxesSubplot:xlabel='experiment', ylabel='F1_class1'>

# %%
# final.groupby([experiment, data]).describe()#.to_csv('../summary/summary.csv')

# %%
# final.groupby([experiment, data]).describe()

# %%
cols = [('test_accuracy', 'mean'), ('test_accuracy', 'std'),
        ('Precision_class1', 'mean'), ('Precision_class1', 'std'),
        ('Recall_class1', 'mean'), ('Recall_class1', 'std'), 
        ('F1_class1', 'mean'), ('F1_class1', 'std')]

# %%
final.groupby([data, experiment]).describe().\
loc[:, cols]
# Out:
#                                    test_accuracy           Precision_class1  \
#                                             mean       std             mean
# data    experiment
# mi_cv   all                             0.570726  0.188574         0.574195
#         all_channels_alphamu            0.571248  0.189627         0.574173
#         bio_channelsConly_alphamu       0.589252  0.187381         0.592344
#         bio_channelsOConly_alphamu      0.581824  0.191220         0.586818
#         bio_channelsOPT                 0.582218  0.186964         0.586421
#         bio_channelsOPT_alphamu         0.584402  0.189488         0.588346
#         bio_channelsOonly_alphamu       0.599018  0.188548         0.604334
#         bio_channelsPT                  0.575224  0.189700         0.578493
#         bio_channelsPT_alphamu          0.575716  0.189432         0.578849
# mi_real all                             0.510865  0.089136         0.507979
#         all_channels_alphamu            0.507019  0.089374         0.502490
#         bio_channelsConly_alphamu       0.526442  0.096509         0.530919
#         bio_channelsOConly_alphamu      0.510625  0.091466         0.512732
#         bio_channelsOPT                 0.522212  0.089175         0.522130
#         bio_channelsOPT_alphamu         0.516538  0.093737         0.515014
#         bio_channelsOonly_alphamu       0.513317  0.094205         0.519279
#         bio_channelsPT                  0.512692  0.097450         0.509192
#         bio_channelsPT_alphamu          0.509712  0.092685         0.505398
#
#                                              Recall_class1            \
#                                          std          mean       std
# data    experiment
# mi_cv   all                         0.215813      0.577574  0.219162
#         all_channels_alphamu        0.216960      0.575894  0.222683
#         bio_channelsConly_alphamu   0.213216      0.598922  0.219186
#         bio_channelsOConly_alphamu  0.216154      0.592112  0.217988
#         bio_channelsOPT             0.214594      0.585985  0.218650
#         bio_channelsOPT_alphamu     0.216596      0.589171  0.220071
#         bio_channelsOonly_alphamu   0.218548      0.601017  0.231754
#         bio_channelsPT              0.216829      0.579544  0.222102
#         bio_channelsPT_alphamu      0.216085      0.583209  0.221776
# mi_real all                         0.092696      0.527981  0.168356
#         all_channels_alphamu        0.093988      0.525769  0.173731
#         bio_channelsConly_alphamu   0.109139      0.532788  0.189709
#         bio_channelsOConly_alphamu  0.098289      0.519038  0.180912
#         bio_channelsOPT             0.095949      0.520673  0.177139
#         bio_channelsOPT_alphamu     0.101050      0.525769  0.187210
#         bio_channelsOonly_alphamu   0.136952      0.496346  0.228183
#         bio_channelsPT              0.103376      0.533558  0.185282
#         bio_channelsPT_alphamu      0.098745      0.530385  0.188391
#
#                                    F1_class1
#                                         mean       std
# data    experiment
# mi_cv   all                         0.562759  0.203576
#         all_channels_alphamu        0.561794  0.206044
#         bio_channelsConly_alphamu   0.582012  0.201443
#         bio_channelsOConly_alphamu  0.576038  0.202780
#         bio_channelsOPT             0.572503  0.202034
#         bio_channelsOPT_alphamu     0.575458  0.204223
#         bio_channelsOonly_alphamu   0.585486  0.209176
#         bio_channelsPT              0.565561  0.205278
#         bio_channelsPT_alphamu      0.567455  0.204516
# mi_real all                         0.509457  0.115926
#         all_channels_alphamu        0.505426  0.120523
#         bio_channelsConly_alphamu   0.516107  0.128251
#         bio_channelsOConly_alphamu  0.502781  0.120111
#         bio_channelsOPT             0.510258  0.119299
#         bio_channelsOPT_alphamu     0.508434  0.126028
#         bio_channelsOonly_alphamu   0.481255  0.153425
#         bio_channelsPT              0.510806  0.128268
#         bio_channelsPT_alphamu      0.506797  0.127264

# %%
final.groupby([data, experiment]).describe()
# Out:
#                                    train_accuracy                      \
#                                             count      mean       std
# data    experiment
# mi_cv   all                                5200.0  0.871398  0.065777
#         all_channels_alphamu               5200.0  0.867095  0.068046
#         bio_channelsConly_alphamu          5200.0  0.766654  0.095958
#         bio_channelsOConly_alphamu         5200.0  0.792249  0.089825
#         bio_channelsOPT                    5200.0  0.825233  0.077415
#         bio_channelsOPT_alphamu            5200.0  0.824876  0.077168
#         bio_channelsOonly_alphamu          5200.0  0.704234  0.121048
#         bio_channelsPT                     5200.0  0.846226  0.070615
#         bio_channelsPT_alphamu             5200.0  0.841459  0.072641
# mi_real all                                 520.0  0.880111  0.063568
#         all_channels_alphamu                520.0  0.875548  0.065210
#         bio_channelsConly_alphamu           520.0  0.775052  0.093396
#         bio_channelsOConly_alphamu          520.0  0.799714  0.088280
#         bio_channelsOPT                     520.0  0.833505  0.075196
#         bio_channelsOPT_alphamu             520.0  0.833430  0.075083
#         bio_channelsOonly_alphamu           520.0  0.709389  0.119584
#         bio_channelsPT                      520.0  0.855244  0.068481
#         bio_channelsPT_alphamu              520.0  0.850008  0.071364
#
#                                                                             \
#                                          min       25%       50%       75%
# data    experiment
# mi_cv   all                         0.675926  0.822222  0.872222  0.905556
#         all_channels_alphamu        0.680556  0.816667  0.866667  0.905556
#         bio_channelsConly_alphamu   0.561111  0.705556  0.738889  0.794444
#         bio_channelsOConly_alphamu  0.605556  0.733333  0.772222  0.822222
#         bio_channelsOPT             0.611111  0.777778  0.811111  0.850000
#         bio_channelsOPT_alphamu     0.648148  0.777778  0.811111  0.850000
#         bio_channelsOonly_alphamu   0.500000  0.622222  0.661111  0.750000
#         bio_channelsPT              0.666667  0.800000  0.838889  0.872222
#         bio_channelsPT_alphamu      0.671296  0.794444  0.833333  0.866667
# mi_real all                         0.723958  0.831250  0.881250  0.912500
#         all_channels_alphamu        0.695833  0.827344  0.875000  0.912500
#         bio_channelsConly_alphamu   0.606250  0.712500  0.750000  0.800000
#         bio_channelsOConly_alphamu  0.631250  0.743750  0.781250  0.830313
#         bio_channelsOPT             0.662500  0.787500  0.818750  0.862500
#         bio_channelsOPT_alphamu     0.679167  0.786458  0.818750  0.862500
#         bio_channelsOonly_alphamu   0.540000  0.630000  0.668750  0.750000
#         bio_channelsPT              0.703125  0.812500  0.850000  0.882812
#         bio_channelsPT_alphamu      0.691667  0.800000  0.843750  0.881250
#
#                                         test_accuracy            ...  \
#                                     max         count      mean  ...
# data    experiment                                               ...
# mi_cv   all                         1.0        5200.0  0.570726  ...
#         all_channels_alphamu        1.0        5200.0  0.571248  ...
#         bio_channelsConly_alphamu   1.0        5200.0  0.589252  ...
#         bio_channelsOConly_alphamu  1.0        5200.0  0.581824  ...
#         bio_channelsOPT             1.0        5200.0  0.582218  ...
#         bio_channelsOPT_alphamu     1.0        5200.0  0.584402  ...
#         bio_channelsOonly_alphamu   1.0        5200.0  0.599018  ...
#         bio_channelsPT              1.0        5200.0  0.575224  ...
#         bio_channelsPT_alphamu      1.0        5200.0  0.575716  ...
# mi_real all                         1.0         520.0  0.510865  ...
#         all_channels_alphamu        1.0         520.0  0.507019  ...
#         bio_channelsConly_alphamu   1.0         520.0  0.526442  ...
#         bio_channelsOConly_alphamu  1.0         520.0  0.510625  ...
#         bio_channelsOPT             1.0         520.0  0.522212  ...
#         bio_channelsOPT_alphamu     1.0         520.0  0.516538  ...
#         bio_channelsOonly_alphamu   1.0         520.0  0.513317  ...
#         bio_channelsPT              1.0         520.0  0.512692  ...
#         bio_channelsPT_alphamu      1.0         520.0  0.509712  ...
#
#                                    F1_class1_train      F1_class2_train  \
#                                                75%  max           count
# data    experiment
# mi_cv   all                               0.909091  1.0          5200.0
#         all_channels_alphamu              0.905028  1.0          5200.0
#         bio_channelsConly_alphamu         0.795322  1.0          5200.0
#         bio_channelsOConly_alphamu        0.824134  1.0          5200.0
#         bio_channelsOPT                   0.852459  1.0          5200.0
#         bio_channelsOPT_alphamu           0.850829  1.0          5200.0
#         bio_channelsOonly_alphamu         0.752718  1.0          5200.0
#         bio_channelsPT                    0.873563  1.0          5200.0
#         bio_channelsPT_alphamu            0.868132  1.0          5200.0
# mi_real all                               0.916263  1.0           520.0
#         all_channels_alphamu              0.912563  1.0           520.0
#         bio_channelsConly_alphamu         0.800000  1.0           520.0
#         bio_channelsOConly_alphamu        0.831208  1.0           520.0
#         bio_channelsOPT                   0.860403  1.0           520.0
#         bio_channelsOPT_alphamu           0.860759  1.0           520.0
#         bio_channelsOonly_alphamu         0.755157  1.0           520.0
#         bio_channelsPT                    0.883268  1.0           520.0
#         bio_channelsPT_alphamu            0.882353  1.0           520.0
#
#                                                                             \
#                                         mean       std       min       25%
# data    experiment
# mi_cv   all                         0.870793  0.066605  0.681818  0.823529
#         all_channels_alphamu        0.866278  0.069024  0.673077  0.818056
#         bio_channelsConly_alphamu   0.764720  0.098062  0.522876  0.700565
#         bio_channelsOConly_alphamu  0.790133  0.092110  0.553459  0.729282
#         bio_channelsOPT             0.825336  0.077958  0.593023  0.777143
#         bio_channelsOPT_alphamu     0.824629  0.077858  0.632258  0.774566
#         bio_channelsOonly_alphamu   0.703101  0.125392  0.220000  0.622754
#         bio_channelsPT              0.845633  0.071630  0.653061  0.797872
#         bio_channelsPT_alphamu      0.840473  0.074053  0.624339  0.791444
# mi_real all                         0.879511  0.064383  0.719577  0.833333
#         all_channels_alphamu        0.874711  0.066393  0.702041  0.827496
#         bio_channelsConly_alphamu   0.772853  0.096521  0.583942  0.711335
#         bio_channelsOConly_alphamu  0.798607  0.089944  0.608696  0.737589
#         bio_channelsOPT             0.833037  0.076115  0.649007  0.784314
#         bio_channelsOPT_alphamu     0.832770  0.076111  0.671233  0.784463
#         bio_channelsOonly_alphamu   0.706563  0.125773  0.376068  0.625812
#         bio_channelsPT              0.854092  0.070257  0.695279  0.810049
#         bio_channelsPT_alphamu      0.848726  0.073297  0.651852  0.800000
#
#
#                                          50%       75%  max
# data    experiment
# mi_cv   all                         0.869565  0.909091  1.0
#         all_channels_alphamu        0.863388  0.906077  1.0
#         bio_channelsConly_alphamu   0.738636  0.795812  1.0
#         bio_channelsOConly_alphamu  0.770115  0.824176  1.0
#         bio_channelsOPT             0.812834  0.852459  1.0
#         bio_channelsOPT_alphamu     0.809249  0.852459  1.0
#         bio_channelsOonly_alphamu   0.669547  0.751226  1.0
#         bio_channelsPT              0.837696  0.875740  1.0
#         bio_channelsPT_alphamu      0.831461  0.869565  1.0
# mi_real all                         0.882373  0.915779  1.0
#         all_channels_alphamu        0.875817  0.914734  1.0
#         bio_channelsConly_alphamu   0.750000  0.807070  1.0
#         bio_channelsOConly_alphamu  0.781065  0.831325  1.0
#         bio_channelsOPT             0.820513  0.860368  1.0
#         bio_channelsOPT_alphamu     0.819035  0.865951  1.0
#         bio_channelsOonly_alphamu   0.675278  0.757865  1.0
#         bio_channelsPT              0.847059  0.886564  1.0
#         bio_channelsPT_alphamu      0.841784  0.877675  1.0
#
# [18 rows x 112 columns]

# %%
final.groupby([data, experiment]).describe().\
loc[:, cols].sort_values(by = [('F1_class1', 'mean')]).drop('mi_real')
# .to_csv('../summary/summary_valMetricsOnly_Class1_sortedByAccuracy_discriminative.csv')
# Out:
# /home/swagmaster/anaconda3/envs/tf/lib/python3.9/site-packages/pandas/core/generic.py:4147: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#                                  test_accuracy           Precision_class1  \
#                                           mean       std             mean
# data  experiment
# mi_cv all_channels_alphamu            0.571248  0.189627         0.574173
#       all                             0.570726  0.188574         0.574195
#       bio_channelsPT                  0.575224  0.189700         0.578493
#       bio_channelsPT_alphamu          0.575716  0.189432         0.578849
#       bio_channelsOPT                 0.582218  0.186964         0.586421
#       bio_channelsOPT_alphamu         0.584402  0.189488         0.588346
#       bio_channelsOConly_alphamu      0.581824  0.191220         0.586818
#       bio_channelsConly_alphamu       0.589252  0.187381         0.592344
#       bio_channelsOonly_alphamu       0.599018  0.188548         0.604334
#
#                                            Recall_class1           F1_class1  \
#                                        std          mean       std      mean
# data  experiment
# mi_cv all_channels_alphamu        0.216960      0.575894  0.222683  0.561794
#       all                         0.215813      0.577574  0.219162  0.562759
#       bio_channelsPT              0.216829      0.579544  0.222102  0.565561
#       bio_channelsPT_alphamu      0.216085      0.583209  0.221776  0.567455
#       bio_channelsOPT             0.214594      0.585985  0.218650  0.572503
#       bio_channelsOPT_alphamu     0.216596      0.589171  0.220071  0.575458
#       bio_channelsOConly_alphamu  0.216154      0.592112  0.217988  0.576038
#       bio_channelsConly_alphamu   0.213216      0.598922  0.219186  0.582012
#       bio_channelsOonly_alphamu   0.218548      0.601017  0.231754  0.585486
#
#
#                                        std
# data  experiment
# mi_cv all_channels_alphamu        0.206044
#       all                         0.203576
#       bio_channelsPT              0.205278
#       bio_channelsPT_alphamu      0.204516
#       bio_channelsOPT             0.202034
#       bio_channelsOPT_alphamu     0.204223
#       bio_channelsOConly_alphamu  0.202780
#       bio_channelsConly_alphamu   0.201443
#       bio_channelsOonly_alphamu   0.209176

# %%
final.sort_values(by = 'Recall_class1').tail(900)
# Out:
#        train_accuracy  test_accuracy  Precision_class1  Precision_class2  \
# 6673         1.000000           1.00          1.000000               1.0
# 6655         1.000000           1.00          1.000000               1.0
# 6656         1.000000           1.00          1.000000               1.0
# 6657         1.000000           1.00          1.000000               1.0
# 6658         1.000000           1.00          1.000000               1.0
# ...               ...            ...               ...               ...
# 39767        1.000000           1.00          1.000000               1.0
# 9653         0.916667           0.85          0.785714               1.0
# 39766        1.000000           1.00          1.000000               1.0
# 39773        1.000000           1.00          1.000000               1.0
# 16870        1.000000           1.00          1.000000               1.0
#
#        Recall_class1  Recall_class2  F1_class1  F1_class2  \
# 6673             1.0       1.000000       1.00        1.0
# 6655             1.0       1.000000       1.00        1.0
# 6656             1.0       1.000000       1.00        1.0
# 6657             1.0       1.000000       1.00        1.0
# 6658             1.0       1.000000       1.00        1.0
# ...              ...            ...        ...        ...
# 39767            1.0       1.000000       1.00        1.0
# 9653             1.0       0.666667       0.88        0.8
# 39766            1.0       1.000000       1.00        1.0
# 39773            1.0       1.000000       1.00        1.0
# 16870            1.0       1.000000       1.00        1.0
#
#        Precision_class1_train  Precision_class2_train  Recall_class1_train  \
# 6673                 1.000000                1.000000             1.000000
# 6655                 1.000000                1.000000             1.000000
# 6656                 1.000000                1.000000             1.000000
# 6657                 1.000000                1.000000             1.000000
# 6658                 1.000000                1.000000             1.000000
# ...                       ...                     ...                  ...
# 39767                1.000000                1.000000             1.000000
# 9653                 0.902174                0.931818             0.932584
# 39766                1.000000                1.000000             1.000000
# 39773                1.000000                1.000000             1.000000
# 16870                1.000000                1.000000             1.000000
#
#        Recall_class2_train  F1_class1_train  F1_class2_train  \
# 6673              1.000000         1.000000         1.000000
# 6655              1.000000         1.000000         1.000000
# 6656              1.000000         1.000000         1.000000
# 6657              1.000000         1.000000         1.000000
# 6658              1.000000         1.000000         1.000000
# ...                    ...              ...              ...
# 39767             1.000000         1.000000         1.000000
# 9653              0.901099         0.917127         0.916201
# 39766             1.000000         1.000000         1.000000
# 39773             1.000000         1.000000         1.000000
# 16870             1.000000         1.000000         1.000000
#
#                       experiment   data
# 6673        all_channels_alphamu  mi_cv
# 6655        all_channels_alphamu  mi_cv
# 6656        all_channels_alphamu  mi_cv
# 6657        all_channels_alphamu  mi_cv
# 6658        all_channels_alphamu  mi_cv
# ...                          ...    ...
# 39767    bio_channelsOPT_alphamu  mi_cv
# 9653        all_channels_alphamu  mi_cv
# 39766    bio_channelsOPT_alphamu  mi_cv
# 39773    bio_channelsOPT_alphamu  mi_cv
# 16870  bio_channelsConly_alphamu  mi_cv
#
# [900 rows x 16 columns]

# %%
import scipy.stats as stats

# %%
# stats.ttest_ind(a=all_cv['test_accuracy'],b=all_cv2['test_accuracy'],equal_var=False)

# %%
cols = [('test_accuracy', 'mean'), ('test_accuracy', 'std'),
        ('Precision_class2', 'mean'), ('Precision_class2', 'std'),
        ('Recall_class2', 'mean'), ('Recall_class2', 'std'), 
        ('F1_class2', 'mean'), ('F1_class2', 'std')]

# %%
final.groupby([experiment, data]).describe().loc[:, cols].sort_values(by = [('test_accuracy', 'mean')]).to_csv('../summary/summary_valMetricsOnly_Class2_sortedByAccuracy.csv')

# %%
final.groupby([data, experiment]).describe().loc[:, (cols)].drop('mi_real').sort_values(by = [('Precision_class1', 'mean')])
# Out:
#                                  test_accuracy           Precision_class1  \
#                                           mean       std             mean
# data  experiment
# mi_cv all_channels_alphamu            0.571248  0.189627         0.574173
#       all                             0.570726  0.188574         0.574195
#       bio_channelsPT                  0.575224  0.189700         0.578493
#       bio_channelsPT_alphamu          0.575716  0.189432         0.578849
#       bio_channelsOPT                 0.582218  0.186964         0.586421
#       bio_channelsOConly_alphamu      0.581824  0.191220         0.586818
#       bio_channelsOPT_alphamu         0.584402  0.189488         0.588346
#       bio_channelsConly_alphamu       0.589252  0.187381         0.592344
#       bio_channelsOonly_alphamu       0.599018  0.188548         0.604334
#
#                                            Recall_class1           F1_class1  \
#                                        std          mean       std      mean
# data  experiment
# mi_cv all_channels_alphamu        0.216960      0.575894  0.222683  0.561794
#       all                         0.215813      0.577574  0.219162  0.562759
#       bio_channelsPT              0.216829      0.579544  0.222102  0.565561
#       bio_channelsPT_alphamu      0.216085      0.583209  0.221776  0.567455
#       bio_channelsOPT             0.214594      0.585985  0.218650  0.572503
#       bio_channelsOConly_alphamu  0.216154      0.592112  0.217988  0.576038
#       bio_channelsOPT_alphamu     0.216596      0.589171  0.220071  0.575458
#       bio_channelsConly_alphamu   0.213216      0.598922  0.219186  0.582012
#       bio_channelsOonly_alphamu   0.218548      0.601017  0.231754  0.585486
#
#
#                                        std
# data  experiment
# mi_cv all_channels_alphamu        0.206044
#       all                         0.203576
#       bio_channelsPT              0.205278
#       bio_channelsPT_alphamu      0.204516
#       bio_channelsOPT             0.202034
#       bio_channelsOConly_alphamu  0.202780
#       bio_channelsOPT_alphamu     0.204223
#       bio_channelsConly_alphamu   0.201443
#       bio_channelsOonly_alphamu   0.209176
